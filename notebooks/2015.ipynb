# %% [markdown]
# # Electricity Use in 2015

# %%
# %pylab inline
import pandas as pd
import import_funcs
#import seaborn as sb
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = import_funcs.BGEdata("new apt")

# %% [markdown]
# Weekly average of daily total use seems to point towards ~10 kWh daily baseload.

# %%
data.USAGE.resample('d', how='sum').resample('w', how='mean').plot()

# %%
plot(data.index.hour, data.USAGE, 'x', color='k')
plot(data.USAGE.groupby(data.index.hour).mean(), color='r')
